# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def parse_athlete_performance(html_content, team):
    """Parses HTML content to extract athlete performance details
    
    Parameters:
    - html_content (str): HTML content of the web page
    - team (str): The name of the team to include in the performance details
    
    Returns:
    - List[Dict]: A list of dictionaries where each dictionary contains performance details of an athlete """
    
    soup = BeautifulSoup(html_content, 'html.parser')
    performances = []

    table = soup.find('table', {'class': 'tablesaw'})
    if not table:
        return performances

    for row in table.find_all('tr')[1:]:
        columns = row.find_all('td')
        if len(columns) == 4:
            performance = {
                'Event Name': columns[0].text.strip(),
                'Athlete Name': columns[1].text.strip(),
                'Team': team,
                'Mark': columns[3].text.strip(),
                'Event Type': 'Individual' if len(columns[1].find_all('a')) == 1 else 'Relay'
            }
            performances.append(performance)

    return performances

# initialize
all_performances = []

# list of school names as they appear in TFRRS
schools = [
    {'Name': 'Florida', 'State': 'FL'},
    {'Name': 'Arkansas', 'State': 'AR'},
    {'Name': 'Stanford', 'State': 'CA'},
    {'Name': 'LSU', 'State': 'LA'},
    {'Name': 'Arizona State', 'State': 'AZ'},
    {'Name': 'Texas Tech', 'State': 'TX'},
    {'Name': 'Georgia', 'State': 'GA'},
    {'Name': 'Alabama', 'State': 'AL'},
    {'Name': 'Washington', 'State': 'WA'},
    {'Name': 'BYU', 'State': 'UT'},
    {'Name': 'Duke', 'State': 'NC'},
    {'Name': 'Georgia Tech', 'State': 'GA'},
    {'Name': 'Brown', 'State': 'RI'},
    {'Name': 'Georgetown_DC', 'State': 'DC'}, # this one had a specific convention
    {'Name': 'Notre Dame_IN', 'State': 'IN'}, # this one had a specific convention
    {'Name': 'Wisconsin', 'State': 'WI'},
    {'Name': 'Rice', 'State': 'TX'},
    {'Name': 'Texas', 'State': 'TX'},
    {'Name': 'USC', 'State': 'CA'},
    {'Name': 'Florida State', 'State': 'FL'},
    {'Name': 'UC San Diego', 'State': 'CA'},
    {'Name': 'Ohio State', 'State': 'OH'},
    {'Name': 'Cornell', 'State': 'NY'},
    {'Name': 'Purdue', 'State': 'IN'},
    {'Name': 'UC Santa Barbara', 'State': 'CA'},
    {'Name': 'Maryland', 'State': 'MD'},
    {'Name': 'UC Davis', 'State': 'CA'},
    {'Name': 'UC Irvine', 'State': 'CA'},
    {'Name': 'Dartmouth', 'State': 'NH'},
    {'Name': 'William__Mary', 'State': 'VA'}, # this one had a specific convention
    {'Name': 'Wake Forest', 'State': 'NC'},
    {'Name': 'Illinois', 'State': 'IL'},
    {'Name': 'Michigan State', 'State': 'MI'},
    {'Name': 'North_Carolina_St', 'State': 'NC'}, # this one had a specific convention
    {'Name': 'Virginia Tech', 'State': 'VA'},
    {'Name': 'Clemson', 'State': 'SC'},
    {'Name': 'Boston_U', 'State': 'MA'}, # this one had a specific convention
    {'Name': 'Minnesota', 'State': 'MN'},
    {'Name': 'Texas_AM', 'State': 'TX'},
    {'Name': 'Rutgers', 'State': 'NJ'},
    {'Name': 'Navy', 'State': 'MD'},
    {'Name': 'Indiana_IN', 'State': 'IN'}, # this one had a specific convention
    {'Name': 'UMass Amherst', 'State': 'MA'},
    {'Name': 'Boston College', 'State': 'MA'},
    {'Name': 'Villanova', 'State': 'PA'}
]

# standard formatting of links in tfrrs
base_url = 'https://www.tfrrs.org/teams/tf/{state}_college_{gender}_{school}.html'

# loop through each school and gender to fetch and parse performances
for school in schools:
    for gender in ['m', 'f']:
        team_name = f"{school['Name']} ({'Men' if gender == 'm' else 'Women'})"
        url = base_url.format(state=school['State'], gender=gender, school=school['Name'].replace(' ', '_'))
        response = requests.get(url)

        # print if failed
        if response.status_code == 200:
            performances = parse_athlete_performance(response.text, team_name)
            all_performances.extend(performances)
        else:
            print(f"Failed to retrieve page for {team_name}")

# convert it into a dataframe
df = pd.DataFrame(all_performances)
df
# Out:
#      Event Name       Athlete Name               Team     Mark  Event Type
# 0            60       McCoy, Wanya      Florida (Men)     6.58  Individual
# 1           200    Gregory, Robert      Florida (Men)    20.40  Individual
# 2           400   Powell, JeVaughn      Florida (Men)    46.28  Individual
# 3           600        Austin, Sam      Florida (Men)  1:16.80  Individual
# 4           800        Austin, Sam      Florida (Men)  1:46.80  Individual
# ...         ...                ...                ...      ...         ...
# 1514         HJ  Clayton, Roschell  Villanova (Women)    1.88m  Individual
# 1515         LJ  Carlson, Caroline  Villanova (Women)    5.62m  Individual
# 1516         TJ        Smith, Gina  Villanova (Women)   11.28m  Individual
# 1517         SP      Retter, Adria  Villanova (Women)   13.78m  Individual
# 1518         WT   Payne, Alexandra  Villanova (Women)   18.15m  Individual
#
# [1519 rows x 5 columns]

# %%
df
# Out:
#      Event Name       Athlete Name               Team     Mark  Event Type
# 0            60       McCoy, Wanya      Florida (Men)     6.58  Individual
# 1           200    Gregory, Robert      Florida (Men)    20.40  Individual
# 2           400   Powell, JeVaughn      Florida (Men)    46.28  Individual
# 3           600        Austin, Sam      Florida (Men)  1:16.80  Individual
# 4           800        Austin, Sam      Florida (Men)  1:46.80  Individual
# ...         ...                ...                ...      ...         ...
# 1514         HJ  Clayton, Roschell  Villanova (Women)    1.88m  Individual
# 1515         LJ  Carlson, Caroline  Villanova (Women)    5.62m  Individual
# 1516         TJ        Smith, Gina  Villanova (Women)   11.28m  Individual
# 1517         SP      Retter, Adria  Villanova (Women)   13.78m  Individual
# 1518         WT   Payne, Alexandra  Villanova (Women)   18.15m  Individual
#
# [1519 rows x 5 columns]

# %% [markdown]
# ### Could add the ability to look at each individual from each of the teams
# 1. Find the link associated with the person's name
# 2. Go to that link
# 3. Access their table of results
#
# ### Could add the ability to automatically find the links themselves
# Option 1:
# 1. Google search 'team name' + 'TFRRS track and field', take top result
#
# Option 2:
# 1. Make it able to detect the team name & state from the link itself
# 2. Have it access results of big meets like NCAAs, BU meets
# 3. Have it detect the typical links for each of those teams, then update the dictionary itself

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from googlesearch import search


def parse_athlete_performance(html_content, team):
    """Parses HTML content to extract athlete performance details
    
    Parameters:
    - html_content (str): HTML content of the web page
    - team (str): The name of the team to include in the performance details
    
    Returns:
    - List[Dict]: A list of dictionaries where each dictionary contains performance details of an athlete """
    
    soup = BeautifulSoup(html_content, 'html.parser')
    performances = []

    table = soup.find('table', {'class': 'tablesaw'})
    if not table:
        return performances

    for row in table.find_all('tr')[1:]:
        columns = row.find_all('td')
        if len(columns) == 4:
            performance = {
                'Event Name': columns[0].text.strip(),
                'Athlete Name': columns[1].text.strip(),
                'Team': team,
                'Mark': columns[3].text.strip(),
                'Event Type': 'Individual' if len(columns[1].find_all('a')) == 1 else 'Relay'
            }
            performances.append(performance)

    return performances

# initialize
all_performances = []

# list of school names as they appear in TFRRS
schools = [
    {'Name': 'Florida', 'State': 'FL'},
    {'Name': 'Arkansas', 'State': 'AR'},
    {'Name': 'Stanford', 'State': 'CA'},
    {'Name': 'LSU', 'State': 'LA'},
    {'Name': 'Arizona State', 'State': 'AZ'},
    {'Name': 'Texas Tech', 'State': 'TX'},
    {'Name': 'Georgia', 'State': 'GA'},
    {'Name': 'Alabama', 'State': 'AL'},
    {'Name': 'Washington', 'State': 'WA'},
    {'Name': 'BYU', 'State': 'UT'},
    {'Name': 'Duke', 'State': 'NC'},
    {'Name': 'Georgia Tech', 'State': 'GA'},
    {'Name': 'Brown', 'State': 'RI'},
    {'Name': 'Georgetown_DC', 'State': 'DC'}, # this one had a specific convention
    {'Name': 'Notre Dame_IN', 'State': 'IN'}, # this one had a specific convention
    {'Name': 'Wisconsin', 'State': 'WI'},
    {'Name': 'Rice', 'State': 'TX'},
    {'Name': 'Texas', 'State': 'TX'},
    {'Name': 'USC', 'State': 'CA'},
    {'Name': 'Florida State', 'State': 'FL'},
    {'Name': 'UC San Diego', 'State': 'CA'},
    {'Name': 'Ohio State', 'State': 'OH'},
    {'Name': 'Cornell', 'State': 'NY'},
    {'Name': 'Purdue', 'State': 'IN'},
    {'Name': 'UC Santa Barbara', 'State': 'CA'},
    {'Name': 'Maryland', 'State': 'MD'},
    {'Name': 'UC Davis', 'State': 'CA'},
    {'Name': 'UC Irvine', 'State': 'CA'},
    {'Name': 'Dartmouth', 'State': 'NH'},
    {'Name': 'William__Mary', 'State': 'VA'}, # this one had a specific convention
    {'Name': 'Wake Forest', 'State': 'NC'},
    {'Name': 'Illinois', 'State': 'IL'},
    {'Name': 'Michigan State', 'State': 'MI'},
    {'Name': 'North_Carolina_St', 'State': 'NC'}, # this one had a specific convention
    {'Name': 'Virginia Tech', 'State': 'VA'},
    {'Name': 'Clemson', 'State': 'SC'},
    {'Name': 'Boston_U', 'State': 'MA'}, # this one had a specific convention
    {'Name': 'Minnesota', 'State': 'MN'},
    {'Name': 'Texas_AM', 'State': 'TX'},
    {'Name': 'Rutgers', 'State': 'NJ'},
    {'Name': 'Navy', 'State': 'MD'},
    {'Name': 'Indiana_IN', 'State': 'IN'}, # this one had a specific convention
    {'Name': 'UMass Amherst', 'State': 'MA'},
    {'Name': 'Boston College', 'State': 'MA'},
    {'Name': 'Villanova', 'State': 'PA'},
    {'Name': 'Alabama A&M', 'State': 'AL'},
    {'Name': 'Alabama-Birmingham', 'State': 'AL'},
    {'Name': 'Murray State', 'State': 'KY'},
    {'Name': 'St. Francis (PA)', 'State': 'PA'},
    {'Name': 'North Carolina Central', 'State': 'NC'},
    {'Name': 'Loyola (IL)', 'State': 'IL'},
    {'Name': 'Chicago State', 'State': 'IL'},
    {'Name': 'Texas A&M-Corpus Christi', 'State': 'TX'},
    {'Name': 'Hampton', 'State': 'VA'},
    {'Name': 'South Carolina State', 'State': 'SC'},
    {'Name': 'Hartford', 'State': 'CT'},
    {'Name': 'Alabama A&M', 'State': 'AL'},

]

def search_google(query):
    """Search Google and return the top website

    Parameters:
    query (str): The search query

    Returns:
    str: The URL of the top website from the search results """
    
    search_results = search(query, num=1, stop=1, pause=2)
    top_website = next(search_results, None)
    return top_website


# standard formatting of links in tfrrs
base_url = 'https://www.tfrrs.org/teams/tf/{state}_college_{gender}_{school}.html'

# loop through each school and gender to fetch and parse performances
for school in schools:
    for gender in ['m', 'f']:
        team_name = f"{school['Name']} ({'Men' if gender == 'm' else 'Women'})"
        url = base_url.format(state=school['State'], gender=gender, school=school['Name'].replace(' ', '_'))
        response = requests.get(url)

        # print if failed
        if response.status_code == 200:
            performances = parse_athlete_performance(response.text, team_name)
            all_performances.extend(performances)
        else:
            print(f"Failed to retrieve page for {team_name}")
            print('Attempting to search the web to retrieve link')
            search_query = f'{team_name} track and field tfrrs'
            
            top_website = search_google(search_query)
            url = top_website
            response = requests.get(url)
            
            # print if failed a second time
            if response.status_code == 200:
                performances = parse_athlete_performance(response.text, team_name)
                all_performances.extend(performances)
                print(f'Failed the first time, but link retreived via google search for {team_name}')
            else:
                print('Failed again')

# convert it into a dataframe
df = pd.DataFrame(all_performances)
df
# Out:
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for Alabama A&M (Men)
# Failed to retrieve page for Alabama A&M (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for Alabama A&M (Women)
# Failed to retrieve page for Alabama-Birmingham (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for Alabama-Birmingham (Men)
# Failed to retrieve page for Alabama-Birmingham (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for Alabama-Birmingham (Women)
# Failed to retrieve page for St. Francis (PA) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for St. Francis (PA) (Men)
# Failed to retrieve page for St. Francis (PA) (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for St. Francis (PA) (Women)
# Failed to retrieve page for North Carolina Central (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for North Carolina Central (Men)
# Failed to retrieve page for North Carolina Central (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for North Carolina Central (Women)
# Failed to retrieve page for Loyola (IL) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for Loyola (IL) (Men)
# Failed to retrieve page for Loyola (IL) (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for Loyola (IL) (Women)
# Failed to retrieve page for Texas A&M-Corpus Christi (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for Texas A&M-Corpus Christi (Men)
# Failed to retrieve page for Texas A&M-Corpus Christi (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for Texas A&M-Corpus Christi (Women)
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for Alabama A&M (Men)
# Failed to retrieve page for Alabama A&M (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retreived via google search for Alabama A&M (Women)
#      Event Name      Athlete Name                 Team     Mark  Event Type
# 0            60      McCoy, Wanya        Florida (Men)     6.58  Individual
# 1           200   Gregory, Robert        Florida (Men)    20.40  Individual
# 2           400  Powell, JeVaughn        Florida (Men)    46.28  Individual
# 3           600       Austin, Sam        Florida (Men)  1:16.80  Individual
# 4           800       Austin, Sam        Florida (Men)  1:46.80  Individual
# ...         ...               ...                  ...      ...         ...
# 1865         LJ    Harden, Miahna  Alabama A&M (Women)    5.94m  Individual
# 1866         TJ    Jamison, Amber  Alabama A&M (Women)   11.45m  Individual
# 1867         SP       Cox, Briana  Alabama A&M (Women)   11.39m  Individual
# 1868         WT       Cox, Briana  Alabama A&M (Women)   18.20m  Individual
# 1869       Pent   Cressey, Ajanae  Alabama A&M (Women)     3125  Individual
#
# [1870 rows x 5 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from googlesearch import search


def parse_athlete_performance(html_content, team):
    """Parses HTML content to extract athlete performance details
    
    Parameters:
    - html_content (str): HTML content of the web page
    - team (str): The name of the team to include in the performance details
    
    Returns:
    - List[Dict]: A list of dictionaries where each dictionary contains performance details of an athlete """
    
    soup = BeautifulSoup(html_content, 'html.parser')
    performances = []

    table = soup.find('table', {'class': 'tablesaw'})
    if not table:
        return performances

    for row in table.find_all('tr')[1:]:
        columns = row.find_all('td')
        if len(columns) == 4:
            performance = {
                'Event Name': columns[0].text.strip(),
                'Athlete Name': columns[1].text.strip(),
                'Team': team,
                'Mark': columns[3].text.strip(),
                'Event Type': 'Individual' if len(columns[1].find_all('a')) == 1 else 'Relay'
            }
            performances.append(performance)

    return performances

# initialize
all_performances = []

# list of school names as they appear in TFRRS
schools = [
    {'Name': 'Florida', 'State': 'FL'},
    {'Name': 'Arkansas', 'State': 'AR'},
    {'Name': 'Stanford', 'State': 'CA'},
    {'Name': 'LSU', 'State': 'LA'},
    {'Name': 'Arizona State', 'State': 'AZ'},
    {'Name': 'Texas Tech', 'State': 'TX'},
    {'Name': 'Georgia', 'State': 'GA'},
    {'Name': 'Alabama', 'State': 'AL'},
    {'Name': 'Washington', 'State': 'WA'},
    {'Name': 'BYU', 'State': 'UT'},
    {'Name': 'Duke', 'State': 'NC'},
    {'Name': 'Georgia Tech', 'State': 'GA'},
    {'Name': 'Brown', 'State': 'RI'},
    {'Name': 'Georgetown_DC', 'State': 'DC'}, # this one had a specific convention
    {'Name': 'Notre Dame_IN', 'State': 'IN'}, # this one had a specific convention
    {'Name': 'Wisconsin', 'State': 'WI'},
    {'Name': 'Rice', 'State': 'TX'},
    {'Name': 'Texas', 'State': 'TX'},
    {'Name': 'USC', 'State': 'CA'},
    {'Name': 'Florida State', 'State': 'FL'},
    {'Name': 'UC San Diego', 'State': 'CA'},
    {'Name': 'Ohio State', 'State': 'OH'},
    {'Name': 'Cornell', 'State': 'NY'},
    {'Name': 'Purdue', 'State': 'IN'},
    {'Name': 'UC Santa Barbara', 'State': 'CA'},
    {'Name': 'Maryland', 'State': 'MD'},
    {'Name': 'UC Davis', 'State': 'CA'},
    {'Name': 'UC Irvine', 'State': 'CA'},
    {'Name': 'Dartmouth', 'State': 'NH'},
    {'Name': 'William__Mary', 'State': 'VA'}, # this one had a specific convention
    {'Name': 'Wake Forest', 'State': 'NC'},
    {'Name': 'Illinois', 'State': 'IL'},
    {'Name': 'Michigan State', 'State': 'MI'},
    {'Name': 'North_Carolina_St', 'State': 'NC'}, # this one had a specific convention
    {'Name': 'Virginia Tech', 'State': 'VA'},
    {'Name': 'Clemson', 'State': 'SC'},
    {'Name': 'Boston_U', 'State': 'MA'}, # this one had a specific convention
    {'Name': 'Minnesota', 'State': 'MN'},
    {'Name': 'Texas_AM', 'State': 'TX'},
    {'Name': 'Rutgers', 'State': 'NJ'},
    {'Name': 'Navy', 'State': 'MD'},
    {'Name': 'Indiana_IN', 'State': 'IN'}, # this one had a specific convention
    {'Name': 'UMass Amherst', 'State': 'MA'},
    {'Name': 'Boston College', 'State': 'MA'},
    {'Name': 'Villanova', 'State': 'PA'},
    {'Name': 'Alabama A&M', 'State': 'AL'},
    {'Name': 'Alabama-Birmingham', 'State': 'AL'},
    {'Name': 'Murray State', 'State': 'KY'},
    {'Name': 'St. Francis (PA)', 'State': 'PA'},
    {'Name': 'North Carolina Central', 'State': 'NC'},
    {'Name': 'Loyola (IL)', 'State': 'IL'},
    {'Name': 'Chicago State', 'State': 'IL'},
    {'Name': 'Texas A&M-Corpus Christi', 'State': 'TX'},
    {'Name': 'Hampton', 'State': 'VA'},
    {'Name': 'South Carolina State', 'State': 'SC'},
    {'Name': 'Hartford', 'State': 'CT'},
    {'Name': 'Alabama A&M', 'State': 'AL'},

]

def search_google(query):
    """Search Google and return the top website

    Parameters:
    query (str): The search query

    Returns:
    str: The URL of the top website from the search results """
    
    search_results = search(query, num=1, stop=1, pause=2)
    top_website = next(search_results, None)
    return top_website


# standard formatting of links in tfrrs
base_url = 'https://www.tfrrs.org/teams/tf/{state}_college_{gender}_{school}.html'

# loop through each school and gender to fetch and parse performances
for school in schools:
    for gender in ['m', 'f']:
        team_name = f"{school['Name']} ({'Men' if gender == 'm' else 'Women'})"
        url = base_url.format(state=school['State'], gender=gender, school=school['Name'].replace(' ', '_'))
        response = requests.get(url)

        # print if failed
        if response.status_code == 200:
            performances = parse_athlete_performance(response.text, team_name)
            all_performances.extend(performances)
            
            # Update the dictionary with the URL in the first pass
            school['URL'] = url
        else:
            print(f"Failed to retrieve page for {team_name}")
            print('Attempting to search the web to retrieve link')
            search_query = f'{team_name} track and field tfrrs'
            
            top_website = search_google(search_query)
            if top_website:
                url = top_website
                response = requests.get(url)
                
                # print if failed a second time
                if response.status_code == 200:
                    performances = parse_athlete_performance(response.text, team_name)
                    all_performances.extend(performances)
                    print(f'Failed the first time, but link retrieved via Google search for {team_name}')
                    
                    # Update the dictionary with the new URL
                    school['URL'] = url
                else:
                    print('Failed again')
            else:
                print('Google search did not return any results for the team')

print(school)
                
# convert it into a dataframe
df = pd.DataFrame(all_performances)
df
# Out:
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# Failed to retrieve page for Alabama A&M (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Women)
# Failed to retrieve page for Alabama-Birmingham (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama-Birmingham (Men)
# Failed to retrieve page for Alabama-Birmingham (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama-Birmingham (Women)
# Failed to retrieve page for St. Francis (PA) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. Francis (PA) (Men)
# Failed to retrieve page for St. Francis (PA) (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. Francis (PA) (Women)
# Failed to retrieve page for North Carolina Central (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for North Carolina Central (Men)
# Failed to retrieve page for North Carolina Central (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for North Carolina Central (Women)
# Failed to retrieve page for Loyola (IL) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Loyola (IL) (Men)
# Failed to retrieve page for Loyola (IL) (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Loyola (IL) (Women)
# Failed to retrieve page for Texas A&M-Corpus Christi (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas A&M-Corpus Christi (Men)
# Failed to retrieve page for Texas A&M-Corpus Christi (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas A&M-Corpus Christi (Women)
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# Failed to retrieve page for Alabama A&M (Women)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Women)
# {'Name': 'Alabama A&M', 'State': 'AL', 'URL': 'https://www.tfrrs.org/teams/tf/AL_college_f_Alabama_AM.html'}
#      Event Name      Athlete Name                 Team     Mark  Event Type
# 0            60      McCoy, Wanya        Florida (Men)     6.58  Individual
# 1           200   Gregory, Robert        Florida (Men)    20.40  Individual
# 2           400  Powell, JeVaughn        Florida (Men)    46.28  Individual
# 3           600       Austin, Sam        Florida (Men)  1:16.80  Individual
# 4           800       Austin, Sam        Florida (Men)  1:46.80  Individual
# ...         ...               ...                  ...      ...         ...
# 1865         LJ    Harden, Miahna  Alabama A&M (Women)    5.94m  Individual
# 1866         TJ    Jamison, Amber  Alabama A&M (Women)   11.45m  Individual
# 1867         SP       Cox, Briana  Alabama A&M (Women)   11.39m  Individual
# 1868         WT       Cox, Briana  Alabama A&M (Women)   18.20m  Individual
# 1869       Pent   Cressey, Ajanae  Alabama A&M (Women)     3125  Individual
#
# [1870 rows x 5 columns]

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from googlesearch import search


def parse_athlete_performance(html_content, team):
    """Parses HTML content to extract athlete performance details
    
    Parameters:
    - html_content (str): HTML content of the web page
    - team (str): The name of the team to include in the performance details
    
    Returns:
    - List[Dict]: A list of dictionaries where each dictionary contains performance details of an athlete """
    
    soup = BeautifulSoup(html_content, 'html.parser')
    performances = []

    table = soup.find('table', {'class': 'tablesaw'})
    if not table:
        return performances

    for row in table.find_all('tr')[1:]:
        columns = row.find_all('td')
        if len(columns) == 4:
            performance = {
                'Event Name': columns[0].text.strip(),
                'Athlete Name': columns[1].text.strip(),
                'Team': team,
                'Mark': columns[3].text.strip(),
                'Event Type': 'Individual' if len(columns[1].find_all('a')) == 1 else 'Relay'
            }
            performances.append(performance)

    return performances

# initialize
all_performances = []

# list of school names as they appear in TFRRS
schools = [
    {'Name': 'Florida', 'State': 'FL'},
    {'Name': 'Arkansas', 'State': 'AR'},
    {'Name': 'Stanford', 'State': 'CA'},
    {'Name': 'LSU', 'State': 'LA'},
    {'Name': 'Arizona State', 'State': 'AZ'},
    {'Name': 'Texas Tech', 'State': 'TX'},
    {'Name': 'Georgia', 'State': 'GA'},
    {'Name': 'Alabama', 'State': 'AL'},
    {'Name': 'Washington', 'State': 'WA'},
    {'Name': 'BYU', 'State': 'UT'},
    {'Name': 'Duke', 'State': 'NC'},
    {'Name': 'Georgia Tech', 'State': 'GA'},
    {'Name': 'Brown', 'State': 'RI'},
    {'Name': 'Georgetown_DC', 'State': 'DC'}, # this one had a specific convention
    {'Name': 'Notre Dame_IN', 'State': 'IN'}, # this one had a specific convention
    {'Name': 'Wisconsin', 'State': 'WI'},
    {'Name': 'Rice', 'State': 'TX'},
    {'Name': 'Texas', 'State': 'TX'},
    {'Name': 'USC', 'State': 'CA'},
    {'Name': 'Florida State', 'State': 'FL'},
    {'Name': 'UC San Diego', 'State': 'CA'},
    {'Name': 'Ohio State', 'State': 'OH'},
    {'Name': 'Cornell', 'State': 'NY'},
    {'Name': 'Purdue', 'State': 'IN'},
    {'Name': 'UC Santa Barbara', 'State': 'CA'},
    {'Name': 'Maryland', 'State': 'MD'},
    {'Name': 'UC Davis', 'State': 'CA'},
    {'Name': 'UC Irvine', 'State': 'CA'},
    {'Name': 'Dartmouth', 'State': 'NH'},
    {'Name': 'William__Mary', 'State': 'VA'}, # this one had a specific convention
    {'Name': 'Wake Forest', 'State': 'NC'},
    {'Name': 'Illinois', 'State': 'IL'},
    {'Name': 'Michigan State', 'State': 'MI'},
    {'Name': 'North_Carolina_St', 'State': 'NC'}, # this one had a specific convention
    {'Name': 'Virginia Tech', 'State': 'VA'},
    {'Name': 'Clemson', 'State': 'SC'},
    {'Name': 'Boston_U', 'State': 'MA'}, # this one had a specific convention
    {'Name': 'Minnesota', 'State': 'MN'},
    {'Name': 'Texas_AM', 'State': 'TX'},
    {'Name': 'Rutgers', 'State': 'NJ'},
    {'Name': 'Navy', 'State': 'MD'},
    {'Name': 'Indiana_IN', 'State': 'IN'}, # this one had a specific convention
    {'Name': 'UMass Amherst', 'State': 'MA'},
    {'Name': 'Boston College', 'State': 'MA'},
    {'Name': 'Villanova', 'State': 'PA'},
    {'Name': 'Alabama A&M', 'State': 'AL'},
    {'Name': 'Alabama-Birmingham', 'State': 'AL'},
    {'Name': 'Murray State', 'State': 'KY'},
    {'Name': 'St. Francis (PA)', 'State': 'PA'},
    {'Name': 'North Carolina Central', 'State': 'NC'},
    {'Name': 'Loyola (IL)', 'State': 'IL'},
    {'Name': 'Chicago State', 'State': 'IL'},
    {'Name': 'Texas A&M-Corpus Christi', 'State': 'TX'},
    {'Name': 'Hampton', 'State': 'VA'},
    {'Name': 'South Carolina State', 'State': 'SC'},
    {'Name': 'Hartford', 'State': 'CT'},
    {'Name': 'Alabama A&M', 'State': 'AL'},

]

def search_google(query):
    """Search Google and return the top website

    Parameters:
    query (str): The search query

    Returns:
    str: The URL of the top website from the search results """
    
    search_results = search(query, num=1, stop=1, pause=2)
    top_website = next(search_results, None)
    return top_website


# standard formatting of links in tfrrs
base_url = 'https://www.tfrrs.org/teams/tf/{state}_college_{gender}_{school}.html'

# Add a 'URLs' key to each school with an empty list to store multiple URLs
for school in schools:
    school['URL'] = []

# loop through each school and gender to fetch and parse performances
for school in schools:
    for gender in ['m', 'f']:
        team_name = f"{school['Name']} ({'Men' if gender == 'm' else 'Women'})"
        url = base_url.format(state=school['State'], gender=gender, school=school['Name'].replace(' ', '_'))
        response = requests.get(url)

        # print if failed
        if response.status_code == 200:
            performances = parse_athlete_performance(response.text, team_name)
            all_performances.extend(performances)
            
            # Append the URL to the list of URLs for the school
            school['URL'].append(url)
            break  # Break the inner loop once URL is successfully retrieved
        else:
            search_query = f'{team_name} track and field tfrrs'
            
            top_website = search_google(search_query)
            if top_website:
                url = top_website
                response = requests.get(url)
                
                # print if failed a second time
                if response.status_code == 200:
                    performances = parse_athlete_performance(response.text, team_name)
                    all_performances.extend(performances)
                    print(f'Failed the first time, but link retrieved via Google search for {team_name}')
                    
                    # Append the URL to the list of URLs for the school
                    school['URL'].append(url)
                    break  # Break the inner loop once URL is successfully retrieved
            else:
                school['URL'].append('')
                print('Google search did not return any results for the team')

# Print out the schools dictionary for manual saving
print(schools)
                
# convert it into a dataframe
df = pd.DataFrame(all_performances)
df
# Out:
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# Failed to retrieve page for Alabama-Birmingham (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama-Birmingham (Men)
# Failed to retrieve page for St. Francis (PA) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. Francis (PA) (Men)
# Failed to retrieve page for North Carolina Central (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for North Carolina Central (Men)
# Failed to retrieve page for Loyola (IL) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Loyola (IL) (Men)
# Failed to retrieve page for Texas A&M-Corpus Christi (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas A&M-Corpus Christi (Men)
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# [{'Name': 'Florida', 'State': 'FL', 'URLs': ['https://www.tfrrs.org/teams/tf/FL_college_m_Florida.html']}, {'Name': 'Arkansas', 'State': 'AR', 'URLs': ['https://www.tfrrs.org/teams/tf/AR_college_m_Arkansas.html']}, {'Name': 'Stanford', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_Stanford.html']}, {'Name': 'LSU', 'State': 'LA', 'URLs': ['https://www.tfrrs.org/teams/tf/LA_college_m_LSU.html']}, {'Name': 'Arizona State', 'State': 'AZ', 'URLs': ['https://www.tfrrs.org/teams/tf/AZ_college_m_Arizona_State.html']}, {'Name': 'Texas Tech', 'State': 'TX', 'URLs': ['https://www.tfrrs.org/teams/tf/TX_college_m_Texas_Tech.html']}, {'Name': 'Georgia', 'State': 'GA', 'URLs': ['https://www.tfrrs.org/teams/tf/GA_college_m_Georgia.html']}, {'Name': 'Alabama', 'State': 'AL', 'URLs': ['https://www.tfrrs.org/teams/tf/AL_college_m_Alabama.html']}, {'Name': 'Washington', 'State': 'WA', 'URLs': ['https://www.tfrrs.org/teams/tf/WA_college_m_Washington.html']}, {'Name': 'BYU', 'State': 'UT', 'URLs': ['https://www.tfrrs.org/teams/tf/UT_college_m_BYU.html']}, {'Name': 'Duke', 'State': 'NC', 'URLs': ['https://www.tfrrs.org/teams/tf/NC_college_m_Duke.html']}, {'Name': 'Georgia Tech', 'State': 'GA', 'URLs': ['https://www.tfrrs.org/teams/tf/GA_college_m_Georgia_Tech.html']}, {'Name': 'Brown', 'State': 'RI', 'URLs': ['https://www.tfrrs.org/teams/tf/RI_college_m_Brown.html']}, {'Name': 'Georgetown_DC', 'State': 'DC', 'URLs': ['https://www.tfrrs.org/teams/tf/DC_college_m_Georgetown_DC.html']}, {'Name': 'Notre Dame_IN', 'State': 'IN', 'URLs': ['https://www.tfrrs.org/teams/tf/IN_college_m_Notre_Dame_IN.html']}, {'Name': 'Wisconsin', 'State': 'WI', 'URLs': ['https://www.tfrrs.org/teams/tf/WI_college_m_Wisconsin.html']}, {'Name': 'Rice', 'State': 'TX', 'URLs': ['https://www.tfrrs.org/teams/tf/TX_college_m_Rice.html']}, {'Name': 'Texas', 'State': 'TX', 'URLs': ['https://www.tfrrs.org/teams/tf/TX_college_m_Texas.html']}, {'Name': 'USC', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_USC.html']}, {'Name': 'Florida State', 'State': 'FL', 'URLs': ['https://www.tfrrs.org/teams/tf/FL_college_m_Florida_State.html']}, {'Name': 'UC San Diego', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_San_Diego.html']}, {'Name': 'Ohio State', 'State': 'OH', 'URLs': ['https://www.tfrrs.org/teams/tf/OH_college_m_Ohio_State.html']}, {'Name': 'Cornell', 'State': 'NY', 'URLs': ['https://www.tfrrs.org/teams/tf/NY_college_m_Cornell.html']}, {'Name': 'Purdue', 'State': 'IN', 'URLs': ['https://www.tfrrs.org/teams/tf/IN_college_m_Purdue.html']}, {'Name': 'UC Santa Barbara', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_Santa_Barbara.html']}, {'Name': 'Maryland', 'State': 'MD', 'URLs': ['https://www.tfrrs.org/teams/tf/MD_college_m_Maryland.html']}, {'Name': 'UC Davis', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_Davis.html']}, {'Name': 'UC Irvine', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_Irvine.html']}, {'Name': 'Dartmouth', 'State': 'NH', 'URLs': ['https://www.tfrrs.org/teams/tf/NH_college_m_Dartmouth.html']}, {'Name': 'William__Mary', 'State': 'VA', 'URLs': ['https://www.tfrrs.org/teams/tf/VA_college_m_William__Mary.html']}, {'Name': 'Wake Forest', 'State': 'NC', 'URLs': ['https://www.tfrrs.org/teams/tf/NC_college_m_Wake_Forest.html']}, {'Name': 'Illinois', 'State': 'IL', 'URLs': ['https://www.tfrrs.org/teams/tf/IL_college_m_Illinois.html']}, {'Name': 'Michigan State', 'State': 'MI', 'URLs': ['https://www.tfrrs.org/teams/tf/MI_college_m_Michigan_State.html']}, {'Name': 'North_Carolina_St', 'State': 'NC', 'URLs': ['https://www.tfrrs.org/teams/tf/NC_college_m_North_Carolina_St.html']}, {'Name': 'Virginia Tech', 'State': 'VA', 'URLs': ['https://www.tfrrs.org/teams/tf/VA_college_m_Virginia_Tech.html']}, {'Name': 'Clemson', 'State': 'SC', 'URLs': ['https://www.tfrrs.org/teams/tf/SC_college_m_Clemson.html']}, {'Name': 'Boston_U', 'State': 'MA', ' ...
#     Event Name      Athlete Name               Team     Mark  Event Type
# 0           60      McCoy, Wanya      Florida (Men)     6.58  Individual
# 1          200   Gregory, Robert      Florida (Men)    20.40  Individual
# 2          400  Powell, JeVaughn      Florida (Men)    46.28  Individual
# 3          600       Austin, Sam      Florida (Men)  1:16.80  Individual
# 4          800       Austin, Sam      Florida (Men)  1:46.80  Individual
# ..         ...               ...                ...      ...         ...
# 879         LJ    Walker, Justin  Alabama A&M (Men)    7.49m  Individual
# 880         TJ    Graham, Joshua  Alabama A&M (Men)   15.20m  Individual
# 881         SP      Davis, Bruce  Alabama A&M (Men)   14.88m  Individual
# 882         WT   Salama, Ezekiel  Alabama A&M (Men)   17.59m  Individual
# 883        Hep    Reaves, Andrew  Alabama A&M (Men)     2811  Individual
#
# [884 rows x 5 columns]

# %%
# 1. Import required libraries

# 2. Define a function to extend the list of top track schools

def extend_top_track_schools(schools):
    """
    Extend the list of top track schools in the NCAA to the top 200.

    Parameters:
    schools (list of dicts): List of dictionaries containing school names and states.

    Returns:
    list of dicts: Extended list of top track schools in the NCAA.
    """

    # 3. Placeholder for the extended list
    extended_schools = [
        {'Name': 'Oregon', 'State': 'OR'},
        {'Name': 'Michigan', 'State': 'MI'},
        {'Name': 'Tennessee', 'State': 'TN'},
        {'Name': 'South Carolina', 'State': 'SC'},
        {'Name': 'Colorado', 'State': 'CO'},
        {'Name': 'Oklahoma', 'State': 'OK'},
        {'Name': 'Penn State', 'State': 'PA'},
        {'Name': 'Kentucky', 'State': 'KY'},
        {'Name': 'Iowa', 'State': 'IA'},
        {'Name': 'Auburn', 'State': 'AL'},
        {'Name': 'Nebraska', 'State': 'NE'},
        {'Name': 'Virginia', 'State': 'VA'},
        {'Name': 'Missouri', 'State': 'MO'},
        {'Name': 'Connecticut', 'State': 'CT'},
        {'Name': 'Mississippi', 'State': 'MS'},
        {'Name': 'Kansas', 'State': 'KS'},
        {'Name': 'Arizona', 'State': 'AZ'},
        {'Name': 'California', 'State': 'CA'},
        {'Name': 'Florida International', 'State': 'FL'},
        {'Name': 'Houston', 'State': 'TX'},
        {'Name': 'Louisville', 'State': 'KY'},
        {'Name': 'Western Michigan', 'State': 'MI'},
        {'Name': 'Alabama-Birmingham', 'State': 'AL'},
        {'Name': 'Southern California', 'State': 'CA'},
        {'Name': 'Oklahoma State', 'State': 'OK'},
        {'Name': 'Central Florida', 'State': 'FL'},
        {'Name': 'Boise State', 'State': 'ID'},
        {'Name': 'Miami (FL)', 'State': 'FL'},
        {'Name': 'North Carolina', 'State': 'NC'},
        {'Name': 'Marquette', 'State': 'WI'},
        {'Name': 'Virginia Commonwealth', 'State': 'VA'},
        {'Name': 'Texas A&M', 'State': 'TX'},
        {'Name': 'Arkansas-Little Rock', 'State': 'AR'},
        {'Name': 'Southern Methodist', 'State': 'TX'},
        {'Name': 'Central Michigan', 'State': 'MI'},
        {'Name': 'Baylor', 'State': 'TX'},
        {'Name': 'Texas-San Antonio', 'State': 'TX'},
        {'Name': 'Cincinnati', 'State': 'OH'},
        {'Name': 'Ohio', 'State': 'OH'},
        {'Name': 'Louisiana Tech', 'State': 'LA'},
        {'Name': 'Washington State', 'State': 'WA'},
        {'Name': 'Florida Atlantic', 'State': 'FL'},
        {'Name': 'Gonzaga', 'State': 'WA'},
        {'Name': 'Virginia Tech', 'State': 'VA'},
        {'Name': 'Utah', 'State': 'UT'},
        {'Name': 'Wisconsin-Milwaukee', 'State': 'WI'},
        {'Name': 'Memphis', 'State': 'TN'},
        {'Name': 'Pittsburgh', 'State': 'PA'},
        {'Name': 'Georgia State', 'State': 'GA'},
        {'Name': 'Tulsa', 'State': 'OK'},
        {'Name': 'North Carolina-Wilmington', 'State': 'NC'},
        {'Name': 'Northern Iowa', 'State': 'IA'},
        {'Name': 'Rider', 'State': 'NJ'},
        {'Name': 'Dayton', 'State': 'OH'},
        {'Name': 'Oregon State', 'State': 'OR'},
        {'Name': "St. John's (NY)", 'State': 'NY'},
        {'Name': 'Louisiana-Lafayette', 'State': 'LA'},
        {'Name': 'Akron', 'State': 'OH'},
        {'Name': 'New Mexico', 'State': 'NM'},
        {'Name': 'Xavier', 'State': 'OH'},
        {'Name': 'Connecticut', 'State': 'CT'},
        {'Name': 'Florida Gulf Coast', 'State': 'FL'},
        {'Name': 'Saint Louis', 'State': 'MO'},
        {'Name': 'Wichita State', 'State': 'KS'},
        {'Name': 'Iona', 'State': 'NY'},
        {'Name': 'Iowa State', 'State': 'IA'},
        {'Name': 'Texas-Arlington', 'State': 'TX'},
        {'Name': 'Florida State', 'State': 'FL'},
        {'Name': 'California-Santa Barbara', 'State': 'CA'},
        {'Name': 'Albany (NY)', 'State': 'NY'},
        {'Name': 'Old Dominion', 'State': 'VA'},
        {'Name': 'Seton Hall', 'State': 'NJ'},
        {'Name': 'Eastern Michigan', 'State': 'MI'},
        {'Name': 'Long Beach State', 'State': 'CA'},
        {'Name': 'Belmont', 'State': 'TN'},
        {'Name': 'Charlotte', 'State': 'NC'},
        {'Name': 'St. Josephs (PA)', 'State': 'PA'},
        {'Name': 'Vanderbilt', 'State': 'TN'},
        {'Name': 'Middle Tennessee', 'State': 'TN'},
        {'Name': 'Northeastern', 'State': 'MA'},
        {'Name': 'Georgetown', 'State': 'DC'},
        {'Name': 'Loyola Marymount', 'State': 'CA'},
        {'Name': 'Louisiana-Monroe', 'State': 'LA'},
        {'Name': 'San Diego State', 'State': 'CA'},
        {'Name': 'Richmond', 'State': 'VA'},
        {'Name': 'East Carolina', 'State': 'NC'},
        {'Name': 'Washington', 'State': 'WA'},
        {'Name': 'Jackson State', 'State': 'MS'},
        {'Name': 'Houston', 'State': 'TX'},
        {'Name': 'Wisconsin-Green Bay', 'State': 'WI'},
        {'Name': 'Detroit Mercy', 'State': 'MI'},
        {'Name': 'UCF', 'State': 'FL'},
        {'Name': 'North Texas', 'State': 'TX'},
        {'Name': 'Southern Mississippi', 'State': 'MS'},
        {'Name': 'Southern Illinois', 'State': 'IL'},
        {'Name': 'Montana', 'State': 'MT'},
        {'Name': 'Florida A&M', 'State': 'FL'},
        {'Name': 'Rice', 'State': 'TX'},
        {'Name': 'Rhode Island', 'State': 'RI'},
        {'Name': 'Valparaiso', 'State': 'IN'},
        {'Name': 'Northwestern', 'State': 'IL'},
        {'Name': 'Hawaii', 'State': 'HI'},
        {'Name': 'Kent State', 'State': 'OH'},
        {'Name': 'UTEP', 'State': 'TX'},
        {'Name': 'Western Kentucky', 'State': 'KY'},
        {'Name': 'Lamar', 'State': 'TX'},
        {'Name': 'Northern Arizona', 'State': 'AZ'},
        {'Name': 'Texas A&M-Corpus Christi', 'State': 'TX'},
        {'Name': 'Marshall', 'State': 'WV'},
        {'Name': 'Yale', 'State': 'CT'},
        {'Name': 'Columbia', 'State': 'NY'},
        {'Name': 'Massachusetts', 'State': 'MA'},
        {'Name': 'Creighton', 'State': 'NE'},
        {'Name': 'Tulane', 'State': 'LA'},
        {'Name': 'Northern Illinois', 'State': 'IL'},
        {'Name': 'Toledo', 'State': 'OH'},
        {'Name': 'Illinois State', 'State': 'IL'},
        {'Name': 'Eastern Kentucky', 'State': 'KY'},
        {'Name': 'UC Riverside', 'State': 'CA'},
        {'Name': 'Loyola (MD)', 'State': 'MD'},
        {'Name': 'Stephen F. Austin', 'State': 'TX'},
        {'Name': 'Eastern Washington', 'State': 'WA'},
        {'Name': 'Texas State', 'State': 'TX'},
        {'Name': 'North Dakota State', 'State': 'ND'},
        {'Name': 'Jacksonville State', 'State': 'AL'},
        {'Name': 'South Alabama', 'State': 'AL'},
        {'Name': 'Liberty', 'State': 'VA'},
        {'Name': 'Georgia Southern', 'State': 'GA'},
        {'Name': 'Portland', 'State': 'OR'},
        {'Name': 'Drake', 'State': 'IA'},
        {'Name': 'Mercer', 'State': 'GA'},
        {'Name': 'Southern Utah', 'State': 'UT'},
        {'Name': 'Southern Illinois-Edwardsville', 'State': 'IL'},
        {'Name': 'UC Santa Barbara', 'State': 'CA'},
        {'Name': 'Western Carolina', 'State': 'NC'},
        {'Name': 'Long Island University', 'State': 'NY'},
        {'Name': 'North Florida', 'State': 'FL'},
        {'Name': 'Winthrop', 'State': 'SC'},
        {'Name': 'Sam Houston State', 'State': 'TX'},
        {'Name': 'East Tennessee State', 'State': 'TN'},
        {'Name': 'Montana State', 'State': 'MT'},
        {'Name': 'Coastal Carolina', 'State': 'SC'},
        {'Name': 'Eastern Illinois', 'State': 'IL'},
        {'Name': 'James Madison', 'State': 'VA'},
        {'Name': 'Gardner-Webb', 'State': 'NC'},
        {'Name': 'Wofford', 'State': 'SC'},
        {'Name': 'South Dakota State', 'State': 'SD'},
        {'Name': 'Alcorn State', 'State': 'MS'},
        {'Name': 'McNeese State', 'State': 'LA'},
        {'Name': 'Bethune-Cookman', 'State': 'FL'},
        {'Name': 'North Carolina A&T', 'State': 'NC'},
        {'Name': 'Delaware', 'State': 'DE'},
        {'Name': 'Southeast Missouri State', 'State': 'MO'},
        {'Name': 'Southern', 'State': 'LA'},
        {'Name': 'Texas-Pan American', 'State': 'TX'},
        {'Name': 'Coppin State', 'State': 'MD'},
        {'Name': 'Binghamton', 'State': 'NY'},
        {'Name': 'Morehead State', 'State': 'KY'},
        {'Name': 'New Hampshire', 'State': 'NH'},
        {'Name': 'South Dakota', 'State': 'SD'},
        {'Name': 'Fordham', 'State': 'NY'},
        {'Name': 'Sacred Heart', 'State': 'CT'},
        {'Name': 'Alabama State', 'State': 'AL'},
        {'Name': 'UMKC', 'State': 'MO'},
        {'Name': 'Manhattan', 'State': 'NY'},
        {'Name': 'IUPUI', 'State': 'IN'},
        {'Name': 'Alabama A&M', 'State': 'AL'},
        {'Name': 'Alabama-Birmingham', 'State': 'AL'},
        {'Name': 'Murray State', 'State': 'KY'},
        {'Name': 'St. Francis (PA)', 'State': 'PA'},
        {'Name': 'North Carolina Central', 'State': 'NC'},
        {'Name': 'Loyola (IL)', 'State': 'IL'},
        {'Name': 'Chicago State', 'State': 'IL'},
        {'Name': 'Texas A&M-Corpus Christi', 'State': 'TX'},
        {'Name': 'Hampton', 'State': 'VA'},
        {'Name': 'South Carolina State', 'State': 'SC'},
        {'Name': 'Hartford', 'State': 'CT'},
        {'Name': 'Alabama A&M', 'State': 'AL'},
        {'Name': 'Howard', 'State': 'DC'},
        {'Name': 'Charleston Southern', 'State': 'SC'},
        {'Name': 'Princeton', 'State': 'NJ'},
        {'Name': 'Lafayette', 'State': 'PA'},
        {'Name': 'Niagara', 'State': 'NY'},
        {'Name': 'St. Bonaventure', 'State': 'NY'},
        {'Name': 'Texas Southern', 'State': 'TX'},
        {'Name': 'Lipscomb', 'State': 'TN'},
        {'Name': 'Eastern Kentucky', 'State': 'KY'},
        {'Name': 'Stony Brook', 'State': 'NY'},
        {'Name': 'Austin Peay', 'State': 'TN'},
        {'Name': 'UNC Greensboro', 'State': 'NC'},
        {'Name': 'Colgate', 'State': 'NY'},
        {'Name': 'Central Connecticut', 'State': 'CT'},
        {'Name': 'South Florida', 'State': 'FL'},
        {'Name': 'Robert Morris', 'State': 'PA'},
        {'Name': 'Florida A&M', 'State': 'FL'},
        {'Name': 'Bryant', 'State': 'RI'},
        {'Name': 'Radford', 'State': 'VA'},
        {'Name': 'Mount St. Marys', 'State': 'MD'},
        {'Name': 'UMBC', 'State': 'MD'},
        {'Name': 'Jacksonville', 'State': 'FL'},
        {'Name': 'Quinnipiac', 'State': 'CT'},
        {'Name': 'Nicholls State', 'State': 'LA'},
        {'Name': 'Fairleigh Dickinson', 'State': 'NJ'},
        {'Name': 'Texas-Rio Grande Valley', 'State': 'TX'},
        {'Name': 'Florida Atlantic', 'State': 'FL'},
        {'Name': 'Kennesaw State', 'State': 'GA'},
        {'Name': 'Savannah State', 'State': 'GA'},
        {'Name': 'UC Davis', 'State': 'CA'},
        {'Name': 'Texas A&M-Corpus Christi', 'State': 'TX'},
        {'Name': 'Grambling', 'State': 'LA'},
        {'Name': 'Stetson', 'State': 'FL'},
        {'Name': 'Alabama A&M', 'State': 'AL'},
        {'Name': 'Howard', 'State': 'DC'},
        {'Name': 'Charleston Southern', 'State': 'SC'},
        {'Name': 'Princeton', 'State': 'NJ'},
        {'Name': 'Lafayette', 'State': 'PA'},
        {'Name': 'Niagara', 'State': 'NY'},
        {'Name': 'St. Bonaventure', 'State': 'NY'},
        {'Name': 'Texas Southern', 'State': 'TX'},
        {'Name': 'Lipscomb', 'State': 'TN'},
        {'Name': 'Eastern Kentucky', 'State': 'KY'},
        {'Name': 'Stony Brook', 'State': 'NY'},
        {'Name': 'Austin Peay', 'State': 'TN'},
        {'Name': 'UNC Greensboro', 'State': 'NC'},
        {'Name': 'Colgate', 'State': 'NY'},
        {'Name': 'Central Connecticut', 'State': 'CT'},
        {'Name': 'South Florida', 'State': 'FL'},
        {'Name': 'Robert Morris', 'State': 'PA'},
        {'Name': 'Florida A&M', 'State': 'FL'},
        {'Name': 'Bryant', 'State': 'RI'},
        {'Name': 'Radford', 'State': 'VA'},
        {'Name': 'UMBC', 'State': 'MD'},
        {'Name': 'Jacksonville', 'State': 'FL'},
        {'Name': 'Quinnipiac', 'State': 'CT'},
        {'Name': 'Nicholls State', 'State': 'LA'},
        {'Name': 'Fairleigh Dickinson', 'State': 'NJ'},
        {'Name': 'Texas-Rio Grande Valley', 'State': 'TX'},
        {'Name': 'Houston Baptist', 'State': 'TX'},
        {'Name': 'Siena', 'State': 'NY'},
        {'Name': 'Western Illinois', 'State': 'IL'},
        {'Name': 'SIU Edwardsville', 'State': 'IL'},
        {'Name': 'Holy Cross', 'State': 'MA'},
        {'Name': 'Central Arkansas', 'State': 'AR'},
        {'Name': 'Elon', 'State': 'NC'},
        {'Name': 'Delaware State', 'State': 'DE'},
        {'Name': 'Central Michigan', 'State': 'MI'},
        {'Name': 'Cal State Bakersfield', 'State': 'CA'},
        {'Name': 'Florida International', 'State': 'FL'},
        {'Name': 'Idaho', 'State': 'ID'},
        {'Name': 'Northern Colorado', 'State': 'CO'},
        {'Name': 'Utah Valley', 'State': 'UT'},
        {'Name': 'Cal Poly', 'State': 'CA'},
        {'Name': 'New Orleans', 'State': 'LA'},
        {'Name': 'Army', 'State': 'NY'},
        {'Name': 'Nevada', 'State': 'NV'},
        {'Name': 'Southeastern Louisiana', 'State': 'LA'},
        {'Name': 'Troy', 'State': 'AL'},
        {'Name': 'UNC Wilmington', 'State': 'NC'},
        {'Name': 'Binghamton', 'State': 'NY'},
        {'Name': 'Radford', 'State': 'VA'},
        {'Name': 'Saint Peters', 'State': 'NJ'},
        {'Name': 'Gardner-Webb', 'State': 'NC'},
        {'Name': 'Idaho State', 'State': 'ID'},
        {'Name': 'Hofstra', 'State': 'NY'},
        {'Name': 'Charleston', 'State': 'SC'},
        {'Name': 'Campbell', 'State': 'NC'},
        {'Name': 'Presbyterian', 'State': 'SC'},
        {'Name': 'UC Irvine', 'State': 'CA'},
        {'Name': 'Western Carolina', 'State': 'NC'},
        {'Name': 'Northern Kentucky', 'State': 'KY'},
        {'Name': 'Kennesaw State', 'State': 'GA'},
        {'Name': 'UNC Asheville', 'State': 'NC'},
        {'Name': 'Albany', 'State': 'NY'},
        {'Name': 'UC Santa Barbara', 'State': 'CA'},
        {'Name': 'Cleveland State', 'State': 'OH'},
        {'Name': 'Tennessee Tech', 'State': 'TN'},
        {'Name': 'Eastern Illinois', 'State': 'IL'},
        {'Name': 'St. Francis (NY)', 'State': 'NY'},
        {'Name': 'Robert Morris', 'State': 'PA'},
        {'Name': 'Arkansas State', 'State': 'AR'},
        {'Name': 'Chicago State', 'State': 'IL'},
        {'Name': 'LIU', 'State': 'NY'},
        {'Name': 'Charleston Southern', 'State': 'SC'},
        {'Name': 'Tennessee State', 'State': 'TN'},
        {'Name': 'Alabama State', 'State': 'AL'},
        {'Name': 'UMKC', 'State': 'MO'},
        {'Name': 'Norfolk State', 'State': 'VA'},
        {'Name': 'Alabama A&M', 'State': 'AL'},
        {'Name': 'Savannah State', 'State': 'GA'},
        {'Name': 'Coppin State', 'State': 'MD'},
        {'Name': 'Alcorn State', 'State': 'MS'},
        {'Name': 'Delaware State', 'State': 'DE'},
        {'Name': 'Jackson State', 'State': 'MS'},
        {'Name': 'Texas Southern', 'State': 'TX'},
        {'Name': 'Prairie View A&M', 'State': 'TX'},
        {'Name': 'Mississippi Valley State', 'State': 'MS'},
        {'Name': 'Florida A&M', 'State': 'FL'},
        {'Name': 'Grambling', 'State': 'LA'},
        {'Name': 'Maryland Eastern Shore', 'State': 'MD'},
        {'Name': 'Southern', 'State': 'LA'},
        {'Name': 'Alabama A&M', 'State': 'AL'},
        {'Name': 'Howard', 'State': 'DC'},
        {'Name': 'Charleston Southern', 'State': 'SC'},
        {'Name': 'Princeton', 'State': 'NJ'},
        {'Name': 'Lafayette', 'State': 'PA'},
        {'Name': 'Niagara', 'State': 'NY'},
        {'Name': 'St. Bonaventure', 'State': 'NY'},
        {'Name': 'Texas Southern', 'State': 'TX'},
        {'Name': 'Lipscomb', 'State': 'TN'},
        {'Name': 'Eastern Kentucky', 'State': 'KY'},
        {'Name': 'Stony Brook', 'State': 'NY'},
        {'Name': 'Austin Peay', 'State': 'TN'},
        {'Name': 'UNC Greensboro', 'State': 'NC'},
        {'Name': 'Colgate', 'State': 'NY'},
        {'Name': 'Central Connecticut', 'State': 'CT'},
        {'Name': 'South Florida', 'State': 'FL'},
        {'Name': 'Robert Morris', 'State': 'PA'},
        {'Name': 'Florida A&M', 'State': 'FL'},
        {'Name': 'Bryant', 'State': 'RI'},
        {'Name': 'Radford', 'State': 'VA'},
        {'Name': 'UMBC', 'State': 'MD'},
        {'Name': 'Jacksonville', 'State': 'FL'},
        {'Name': 'Quinnipiac', 'State': 'CT'},
        {'Name': 'Nicholls State', 'State': 'LA'},
        {'Name': 'Fairleigh Dickinson', 'State': 'NJ'},
        {'Name': 'Texas-Rio Grande Valley', 'State': 'TX'},
        {'Name': 'Houston Baptist', 'State': 'TX'},
        {'Name': 'Siena', 'State': 'NY'},
        {'Name': 'Western Illinois', 'State': 'IL'},
        {'Name': 'SIU Edwardsville', 'State': 'IL'},
        {'Name': 'Holy Cross', 'State': 'MA'},
        {'Name': 'Central Arkansas', 'State': 'AR'},
        {'Name': 'Elon', 'State': 'NC'},
        {'Name': 'Delaware State', 'State': 'DE'},
        {'Name': 'Central Michigan', 'State': 'MI'},
        {'Name': 'Cal State Bakersfield', 'State': 'CA'},
        {'Name': 'Florida International', 'State': 'FL'},
        {'Name': 'Idaho', 'State': 'ID'},
        {'Name': 'Northern Colorado', 'State': 'CO'},
        {'Name': 'Utah Valley', 'State': 'UT'},
        {'Name': 'Cal Poly', 'State': 'CA'},
        {'Name': 'New Orleans', 'State': 'LA'},
        {'Name': 'Army', 'State': 'NY'},
        {'Name': 'Nevada', 'State': 'NV'},
        {'Name': 'Southeastern Louisiana', 'State': 'LA'},
        {'Name': 'Troy', 'State': 'AL'},
        {'Name': 'UNC Wilmington', 'State': 'NC'},
        {'Name': 'Binghamton', 'State': 'NY'},
        {'Name': 'Radford', 'State': 'VA'},
        {'Name': 'Gardner-Webb', 'State': 'NC'},
        {'Name': 'Idaho State', 'State': 'ID'},
        {'Name': 'Hofstra', 'State': 'NY'},
        {'Name': 'Charleston', 'State': 'SC'},
        {'Name': 'Campbell', 'State': 'NC'},
        {'Name': 'Presbyterian', 'State': 'SC'},
        {'Name': 'UC Irvine', 'State': 'CA'},
        {'Name': 'Western Carolina', 'State': 'NC'},
        {'Name': 'Northern Kentucky', 'State': 'KY'},
        {'Name': 'Kennesaw State', 'State': 'GA'},
        {'Name': 'UNC Asheville', 'State': 'NC'},
        {'Name': 'Albany', 'State': 'NY'},
        {'Name': 'UC Santa Barbara', 'State': 'CA'},
        {'Name': 'Cleveland State', 'State': 'OH'},
        {'Name': 'Tennessee Tech', 'State': 'TN'},
        {'Name': 'Eastern Illinois', 'State': 'IL'},
        {'Name': 'St. Francis (NY)', 'State': 'NY'},
        {'Name': 'Robert Morris', 'State': 'PA'},
        {'Name': 'Arkansas State', 'State': 'AR'},
        {'Name': 'Chicago State', 'State': 'IL'},
        {'Name': 'LIU', 'State': 'NY'},
        {'Name': 'Charleston Southern', 'State': 'SC'},
        {'Name': 'Tennessee State', 'State': 'TN'},
        {'Name': 'Alabama State', 'State': 'AL'},
        {'Name': 'UMKC', 'State': 'MO'},
        {'Name': 'Norfolk State', 'State': 'VA'},
        {'Name': 'Alabama A&M', 'State': 'AL'},
        {'Name': 'Savannah State', 'State': 'GA'},
        {'Name': 'Coppin State', 'State': 'MD'},
        {'Name': 'Alcorn State', 'State': 'MS'},
        {'Name': 'Delaware State', 'State': 'DE'},
        {'Name': 'Jackson State', 'State': 'MS'},
        {'Name': 'Texas Southern', 'State': 'TX'},
        {'Name': 'Prairie View A&M', 'State': 'TX'},
        {'Name': 'Mississippi Valley State', 'State': 'MS'},
        {'Name': 'Florida A&M', 'State': 'FL'},
        {'Name': 'Grambling', 'State': 'LA'},
        {'Name': 'Maryland Eastern Shore', 'State': 'MD'},
        {'Name': 'Southern', 'State': 'LA'}
    ]
    
    # 4. Return the extended list
    return schools + extended_schools

# 5. Call the function to extend the list of top track schools
extended_schools_list = extend_top_track_schools(schools)

import requests
from bs4 import BeautifulSoup
import pandas as pd
from googlesearch import search


def parse_athlete_performance(html_content, team):
    """Parses HTML content to extract athlete performance details
    
    Parameters:
    - html_content (str): HTML content of the web page
    - team (str): The name of the team to include in the performance details
    
    Returns:
    - List[Dict]: A list of dictionaries where each dictionary contains performance details of an athlete """
    
    soup = BeautifulSoup(html_content, 'html.parser')
    performances = []

    table = soup.find('table', {'class': 'tablesaw'})
    if not table:
        return performances

    for row in table.find_all('tr')[1:]:
        columns = row.find_all('td')
        if len(columns) == 4:
            performance = {
                'Event Name': columns[0].text.strip(),
                'Athlete Name': columns[1].text.strip(),
                'Team': team,
                'Mark': columns[3].text.strip(),
                'Event Type': 'Individual' if len(columns[1].find_all('a')) == 1 else 'Relay'
            }
            performances.append(performance)

    return performances

# initialize
all_performances = []

def search_google(query):
    """Search Google and return the top website

    Parameters:
    query (str): The search query

    Returns:
    str: The URL of the top website from the search results """
    
    search_results = search(query, num=1, stop=1, pause=2)
    top_website = next(search_results, None)
    return top_website

# standard formatting of links in tfrrs
base_url = 'https://www.tfrrs.org/teams/tf/{state}_college_{gender}_{school}.html'

# Add a 'URLs' key to each school with an empty list to store multiple URLs
for school in extended_schools_list:
    school['URLs'] = []

# loop through each school and gender to fetch and parse performances
for school in extended_schools_list:
    for gender in ['m', 'f']:
        team_name = f"{school['Name']} ({'Men' if gender == 'm' else 'Women'})"
        url = base_url.format(state=school['State'], gender=gender, school=school['Name'].replace(' ', '_'))
        response = requests.get(url)

        # print if failed
        if response.status_code == 200:
            performances = parse_athlete_performance(response.text, team_name)
            all_performances.extend(performances)
            
            # Append the URL to the list of URLs for the school
            school['URL'].append(url)
            break  # Break the inner loop once URL is successfully retrieved
        else:
            print(f"Failed to retrieve page for {team_name}")
            print('Attempting to search the web to retrieve link')
            search_query = f'{team_name} track and field tfrrs'
            
            top_website = search_google(search_query)
            if top_website:
                url = top_website
                response = requests.get(url)
                
                # print if failed a second time
                if response.status_code == 200:
                    performances = parse_athlete_performance(response.text, team_name)
                    all_performances.extend(performances)
                    print(f'Failed the first time, but link retrieved via Google search for {team_name}')
                    
                    # Append the URL to the list of URLs for the school
                    school['URL'].append(url)
                    break  # Break the inner loop once URL is successfully retrieved
                else:
                    print('Failed again')
            else:
                print('Google search did not return any results for the team')

# Print out the schools dictionary for manual saving
print(schools)
                
# convert it into a dataframe
df = pd.DataFrame(all_performances)
df
# Out:
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# Failed to retrieve page for Alabama-Birmingham (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama-Birmingham (Men)
# Failed to retrieve page for St. Francis (PA) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. Francis (PA) (Men)
# Failed to retrieve page for North Carolina Central (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for North Carolina Central (Men)
# Failed to retrieve page for Loyola (IL) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Loyola (IL) (Men)
# Failed to retrieve page for Texas A&M-Corpus Christi (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas A&M-Corpus Christi (Men)
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# Failed to retrieve page for California (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for California (Men)
# Failed to retrieve page for Florida International (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Florida International (Men)
# Failed to retrieve page for Alabama-Birmingham (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama-Birmingham (Men)
# Failed to retrieve page for Southern California (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Southern California (Men)
# Failed to retrieve page for Miami (FL) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Miami (FL) (Men)
# Failed to retrieve page for Virginia Commonwealth (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Virginia Commonwealth (Men)
# Failed to retrieve page for Texas A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas A&M (Men)
# Failed to retrieve page for Arkansas-Little Rock (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Arkansas-Little Rock (Men)
# Failed to retrieve page for Southern Methodist (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Southern Methodist (Men)
# Failed to retrieve page for Texas-San Antonio (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas-San Antonio (Men)
# Failed to retrieve page for Ohio (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Ohio (Men)
# Failed to retrieve page for Wisconsin-Milwaukee (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Wisconsin-Milwaukee (Men)
# Failed to retrieve page for North Carolina-Wilmington (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for North Carolina-Wilmington (Men)
# Failed to retrieve page for St. John's (NY) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. John's (NY) (Men)
# Failed to retrieve page for Louisiana-Lafayette (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Louisiana-Lafayette (Men)
# Failed to retrieve page for Saint Louis (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Saint Louis (Men)
# Failed to retrieve page for Texas-Arlington (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas-Arlington (Men)
# Failed to retrieve page for California-Santa Barbara (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for California-Santa Barbara (Men)
# Failed to retrieve page for Albany (NY) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Albany (NY) (Men)
# Failed to retrieve page for Old Dominion (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Old Dominion (Men)
# Failed to retrieve page for Long Beach State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Long Beach State (Men)
# Failed to retrieve page for St. Josephs (PA) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. Josephs (PA) (Men)
# Failed to retrieve page for Middle Tennessee (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Middle Tennessee (Men)
# Failed to retrieve page for Georgetown (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Georgetown (Men)
# Failed to retrieve page for Louisiana-Monroe (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Louisiana-Monroe (Men)
# Failed to retrieve page for Wisconsin-Green Bay (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Wisconsin-Green Bay (Men)
# Failed to retrieve page for UCF (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for UCF (Men)
# Failed to retrieve page for Southern Mississippi (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Southern Mississippi (Men)
# Failed to retrieve page for Florida A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Florida A&M (Men)
# Failed to retrieve page for Northwestern (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Northwestern (Men)
# Failed to retrieve page for Texas A&M-Corpus Christi (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas A&M-Corpus Christi (Men)
# Failed to retrieve page for Massachusetts (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Massachusetts (Men)
# Failed to retrieve page for Northern Illinois (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Northern Illinois (Men)
# Failed to retrieve page for Loyola (MD) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Loyola (MD) (Men)
# Failed to retrieve page for Stephen F. Austin (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Stephen F. Austin (Men)
# Failed to retrieve page for North Dakota State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for North Dakota State (Men)
# Failed to retrieve page for Jacksonville State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Jacksonville State (Men)
# Failed to retrieve page for Southern Illinois-Edwardsville (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Southern Illinois-Edwardsville (Men)
# Failed to retrieve page for Long Island University (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Long Island University (Men)
# Failed to retrieve page for Sam Houston State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Sam Houston State (Men)
# Failed to retrieve page for East Tennessee State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for East Tennessee State (Men)
# Failed to retrieve page for Gardner-Webb (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Gardner-Webb (Men)
# Failed to retrieve page for South Dakota State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for South Dakota State (Men)
# Failed to retrieve page for Bethune-Cookman (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Bethune-Cookman (Men)
# Failed to retrieve page for North Carolina A&T (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for North Carolina A&T (Men)
# Failed to retrieve page for Southeast Missouri State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Southeast Missouri State (Men)
# Failed to retrieve page for Texas-Pan American (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas-Pan American (Men)
# Failed to retrieve page for UMKC (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for UMKC (Men)
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# Failed to retrieve page for Alabama-Birmingham (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama-Birmingham (Men)
# Failed to retrieve page for St. Francis (PA) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. Francis (PA) (Men)
# Failed to retrieve page for North Carolina Central (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for North Carolina Central (Men)
# Failed to retrieve page for Loyola (IL) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Loyola (IL) (Men)
# Failed to retrieve page for Texas A&M-Corpus Christi (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas A&M-Corpus Christi (Men)
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# Failed to retrieve page for St. Bonaventure (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. Bonaventure (Men)
# Failed to retrieve page for Robert Morris (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Robert Morris (Men)
# Failed to retrieve page for Florida A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Florida A&M (Men)
# Failed to retrieve page for Mount St. Marys (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Mount St. Marys (Men)
# Failed to retrieve page for Fairleigh Dickinson (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Fairleigh Dickinson (Men)
# Failed to retrieve page for Texas-Rio Grande Valley (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas-Rio Grande Valley (Men)
# Failed to retrieve page for Texas A&M-Corpus Christi (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas A&M-Corpus Christi (Men)
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# Failed to retrieve page for St. Bonaventure (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. Bonaventure (Men)
# Failed to retrieve page for Robert Morris (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Robert Morris (Men)
# Failed to retrieve page for Florida A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Florida A&M (Men)
# Failed to retrieve page for Fairleigh Dickinson (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Fairleigh Dickinson (Men)
# Failed to retrieve page for Texas-Rio Grande Valley (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas-Rio Grande Valley (Men)
# Failed to retrieve page for Houston Baptist (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Houston Baptist (Men)
# Failed to retrieve page for Cal State Bakersfield (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Cal State Bakersfield (Men)
# Failed to retrieve page for Florida International (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Florida International (Men)
# Failed to retrieve page for Army (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Army (Men)
# Failed to retrieve page for Southeastern Louisiana (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Southeastern Louisiana (Men)
# Failed to retrieve page for Saint Peters (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Saint Peters (Men)
# Failed to retrieve page for Gardner-Webb (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Gardner-Webb (Men)
# Failed to retrieve page for Charleston (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Charleston (Men)
# Failed to retrieve page for Cleveland State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Cleveland State (Men)
# Failed to retrieve page for St. Francis (NY) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. Francis (NY) (Men)
# Failed to retrieve page for Robert Morris (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Robert Morris (Men)
# Failed to retrieve page for LIU (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for LIU (Men)
# Failed to retrieve page for Tennessee State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Tennessee State (Men)
# Failed to retrieve page for UMKC (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for UMKC (Men)
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# Failed to retrieve page for Prairie View A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Prairie View A&M (Men)
# Failed to retrieve page for Mississippi Valley State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Mississippi Valley State (Men)
# Failed to retrieve page for Florida A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Florida A&M (Men)
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# Failed to retrieve page for St. Bonaventure (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. Bonaventure (Men)
# Failed to retrieve page for Robert Morris (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Robert Morris (Men)
# Failed to retrieve page for Florida A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Florida A&M (Men)
# Failed to retrieve page for Fairleigh Dickinson (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Fairleigh Dickinson (Men)
# Failed to retrieve page for Texas-Rio Grande Valley (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Texas-Rio Grande Valley (Men)
# Failed to retrieve page for Houston Baptist (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Houston Baptist (Men)
# Failed to retrieve page for Cal State Bakersfield (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Cal State Bakersfield (Men)
# Failed to retrieve page for Florida International (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Florida International (Men)
# Failed to retrieve page for Army (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Army (Men)
# Failed to retrieve page for Southeastern Louisiana (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Southeastern Louisiana (Men)
# Failed to retrieve page for Gardner-Webb (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Gardner-Webb (Men)
# Failed to retrieve page for Charleston (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Charleston (Men)
# Failed to retrieve page for Cleveland State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Cleveland State (Men)
# Failed to retrieve page for St. Francis (NY) (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for St. Francis (NY) (Men)
# Failed to retrieve page for Robert Morris (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Robert Morris (Men)
# Failed to retrieve page for LIU (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for LIU (Men)
# Failed to retrieve page for Tennessee State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Tennessee State (Men)
# Failed to retrieve page for UMKC (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for UMKC (Men)
# Failed to retrieve page for Alabama A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Alabama A&M (Men)
# Failed to retrieve page for Prairie View A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Prairie View A&M (Men)
# Failed to retrieve page for Mississippi Valley State (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Mississippi Valley State (Men)
# Failed to retrieve page for Florida A&M (Men)
# Attempting to search the web to retrieve link
# Failed the first time, but link retrieved via Google search for Florida A&M (Men)
# [{'Name': 'Florida', 'State': 'FL', 'URLs': ['https://www.tfrrs.org/teams/tf/FL_college_m_Florida.html']}, {'Name': 'Arkansas', 'State': 'AR', 'URLs': ['https://www.tfrrs.org/teams/tf/AR_college_m_Arkansas.html']}, {'Name': 'Stanford', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_Stanford.html']}, {'Name': 'LSU', 'State': 'LA', 'URLs': ['https://www.tfrrs.org/teams/tf/LA_college_m_LSU.html']}, {'Name': 'Arizona State', 'State': 'AZ', 'URLs': ['https://www.tfrrs.org/teams/tf/AZ_college_m_Arizona_State.html']}, {'Name': 'Texas Tech', 'State': 'TX', 'URLs': ['https://www.tfrrs.org/teams/tf/TX_college_m_Texas_Tech.html']}, {'Name': 'Georgia', 'State': 'GA', 'URLs': ['https://www.tfrrs.org/teams/tf/GA_college_m_Georgia.html']}, {'Name': 'Alabama', 'State': 'AL', 'URLs': ['https://www.tfrrs.org/teams/tf/AL_college_m_Alabama.html']}, {'Name': 'Washington', 'State': 'WA', 'URLs': ['https://www.tfrrs.org/teams/tf/WA_college_m_Washington.html']}, {'Name': 'BYU', 'State': 'UT', 'URLs': ['https://www.tfrrs.org/teams/tf/UT_college_m_BYU.html']}, {'Name': 'Duke', 'State': 'NC', 'URLs': ['https://www.tfrrs.org/teams/tf/NC_college_m_Duke.html']}, {'Name': 'Georgia Tech', 'State': 'GA', 'URLs': ['https://www.tfrrs.org/teams/tf/GA_college_m_Georgia_Tech.html']}, {'Name': 'Brown', 'State': 'RI', 'URLs': ['https://www.tfrrs.org/teams/tf/RI_college_m_Brown.html']}, {'Name': 'Georgetown_DC', 'State': 'DC', 'URLs': ['https://www.tfrrs.org/teams/tf/DC_college_m_Georgetown_DC.html']}, {'Name': 'Notre Dame_IN', 'State': 'IN', 'URLs': ['https://www.tfrrs.org/teams/tf/IN_college_m_Notre_Dame_IN.html']}, {'Name': 'Wisconsin', 'State': 'WI', 'URLs': ['https://www.tfrrs.org/teams/tf/WI_college_m_Wisconsin.html']}, {'Name': 'Rice', 'State': 'TX', 'URLs': ['https://www.tfrrs.org/teams/tf/TX_college_m_Rice.html']}, {'Name': 'Texas', 'State': 'TX', 'URLs': ['https://www.tfrrs.org/teams/tf/TX_college_m_Texas.html']}, {'Name': 'USC', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_USC.html']}, {'Name': 'Florida State', 'State': 'FL', 'URLs': ['https://www.tfrrs.org/teams/tf/FL_college_m_Florida_State.html']}, {'Name': 'UC San Diego', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_San_Diego.html']}, {'Name': 'Ohio State', 'State': 'OH', 'URLs': ['https://www.tfrrs.org/teams/tf/OH_college_m_Ohio_State.html']}, {'Name': 'Cornell', 'State': 'NY', 'URLs': ['https://www.tfrrs.org/teams/tf/NY_college_m_Cornell.html']}, {'Name': 'Purdue', 'State': 'IN', 'URLs': ['https://www.tfrrs.org/teams/tf/IN_college_m_Purdue.html']}, {'Name': 'UC Santa Barbara', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_Santa_Barbara.html']}, {'Name': 'Maryland', 'State': 'MD', 'URLs': ['https://www.tfrrs.org/teams/tf/MD_college_m_Maryland.html']}, {'Name': 'UC Davis', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_Davis.html']}, {'Name': 'UC Irvine', 'State': 'CA', 'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_Irvine.html']}, {'Name': 'Dartmouth', 'State': 'NH', 'URLs': ['https://www.tfrrs.org/teams/tf/NH_college_m_Dartmouth.html']}, {'Name': 'William__Mary', 'State': 'VA', 'URLs': ['https://www.tfrrs.org/teams/tf/VA_college_m_William__Mary.html']}, {'Name': 'Wake Forest', 'State': 'NC', 'URLs': ['https://www.tfrrs.org/teams/tf/NC_college_m_Wake_Forest.html']}, {'Name': 'Illinois', 'State': 'IL', 'URLs': ['https://www.tfrrs.org/teams/tf/IL_college_m_Illinois.html']}, {'Name': 'Michigan State', 'State': 'MI', 'URLs': ['https://www.tfrrs.org/teams/tf/MI_college_m_Michigan_State.html']}, {'Name': 'North_Carolina_St', 'State': 'NC', 'URLs': ['https://www.tfrrs.org/teams/tf/NC_college_m_North_Carolina_St.html']}, {'Name': 'Virginia Tech', 'State': 'VA', 'URLs': ['https://www.tfrrs.org/teams/tf/VA_college_m_Virginia_Tech.html']}, {'Name': 'Clemson', 'State': 'SC', 'URLs': ['https://www.tfrrs.org/teams/tf/SC_college_m_Clemson.html']}, {'Name': 'Boston_U', 'State': 'MA', ' ...
#      Event Name      Athlete Name            Team     Mark  Event Type
# 0            60      McCoy, Wanya   Florida (Men)     6.58  Individual
# 1           200   Gregory, Robert   Florida (Men)    20.40  Individual
# 2           400  Powell, JeVaughn   Florida (Men)    46.28  Individual
# 3           600       Austin, Sam   Florida (Men)  1:16.80  Individual
# 4           800       Austin, Sam   Florida (Men)  1:46.80  Individual
# ...         ...               ...             ...      ...         ...
# 5907         HJ      Smith, Roman  Southern (Men)    2.14m  Individual
# 5908         LJ     Wenddern, Koi  Southern (Men)    7.25m  Individual
# 5909         TJ   Hamilton, Kevon  Southern (Men)   15.02m  Individual
# 5910         SP      Smith, Mehki  Southern (Men)   14.42m  Individual
# 5911         WT    Adolph, Calvin  Southern (Men)   14.26m  Individual
#
# [5912 rows x 5 columns]

# %%
schools
# Out:
# [{'Name': 'Florida',
#   'State': 'FL',
#   'URLs': ['https://www.tfrrs.org/teams/tf/FL_college_m_Florida.html']},
#  {'Name': 'Arkansas',
#   'State': 'AR',
#   'URLs': ['https://www.tfrrs.org/teams/tf/AR_college_m_Arkansas.html']},
#  {'Name': 'Stanford',
#   'State': 'CA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_Stanford.html']},
#  {'Name': 'LSU',
#   'State': 'LA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/LA_college_m_LSU.html']},
#  {'Name': 'Arizona State',
#   'State': 'AZ',
#   'URLs': ['https://www.tfrrs.org/teams/tf/AZ_college_m_Arizona_State.html']},
#  {'Name': 'Texas Tech',
#   'State': 'TX',
#   'URLs': ['https://www.tfrrs.org/teams/tf/TX_college_m_Texas_Tech.html']},
#  {'Name': 'Georgia',
#   'State': 'GA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/GA_college_m_Georgia.html']},
#  {'Name': 'Alabama',
#   'State': 'AL',
#   'URLs': ['https://www.tfrrs.org/teams/tf/AL_college_m_Alabama.html']},
#  {'Name': 'Washington',
#   'State': 'WA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/WA_college_m_Washington.html']},
#  {'Name': 'BYU',
#   'State': 'UT',
#   'URLs': ['https://www.tfrrs.org/teams/tf/UT_college_m_BYU.html']},
#  {'Name': 'Duke',
#   'State': 'NC',
#   'URLs': ['https://www.tfrrs.org/teams/tf/NC_college_m_Duke.html']},
#  {'Name': 'Georgia Tech',
#   'State': 'GA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/GA_college_m_Georgia_Tech.html']},
#  {'Name': 'Brown',
#   'State': 'RI',
#   'URLs': ['https://www.tfrrs.org/teams/tf/RI_college_m_Brown.html']},
#  {'Name': 'Georgetown_DC',
#   'State': 'DC',
#   'URLs': ['https://www.tfrrs.org/teams/tf/DC_college_m_Georgetown_DC.html']},
#  {'Name': 'Notre Dame_IN',
#   'State': 'IN',
#   'URLs': ['https://www.tfrrs.org/teams/tf/IN_college_m_Notre_Dame_IN.html']},
#  {'Name': 'Wisconsin',
#   'State': 'WI',
#   'URLs': ['https://www.tfrrs.org/teams/tf/WI_college_m_Wisconsin.html']},
#  {'Name': 'Rice',
#   'State': 'TX',
#   'URLs': ['https://www.tfrrs.org/teams/tf/TX_college_m_Rice.html']},
#  {'Name': 'Texas',
#   'State': 'TX',
#   'URLs': ['https://www.tfrrs.org/teams/tf/TX_college_m_Texas.html']},
#  {'Name': 'USC',
#   'State': 'CA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_USC.html']},
#  {'Name': 'Florida State',
#   'State': 'FL',
#   'URLs': ['https://www.tfrrs.org/teams/tf/FL_college_m_Florida_State.html']},
#  {'Name': 'UC San Diego',
#   'State': 'CA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_San_Diego.html']},
#  {'Name': 'Ohio State',
#   'State': 'OH',
#   'URLs': ['https://www.tfrrs.org/teams/tf/OH_college_m_Ohio_State.html']},
#  {'Name': 'Cornell',
#   'State': 'NY',
#   'URLs': ['https://www.tfrrs.org/teams/tf/NY_college_m_Cornell.html']},
#  {'Name': 'Purdue',
#   'State': 'IN',
#   'URLs': ['https://www.tfrrs.org/teams/tf/IN_college_m_Purdue.html']},
#  {'Name': 'UC Santa Barbara',
#   'State': 'CA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_Santa_Barbara.html']},
#  {'Name': 'Maryland',
#   'State': 'MD',
#   'URLs': ['https://www.tfrrs.org/teams/tf/MD_college_m_Maryland.html']},
#  {'Name': 'UC Davis',
#   'State': 'CA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_Davis.html']},
#  {'Name': 'UC Irvine',
#   'State': 'CA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/CA_college_m_UC_Irvine.html']},
#  {'Name': 'Dartmouth',
#   'State': 'NH',
#   'URLs': ['https://www.tfrrs.org/teams/tf/NH_college_m_Dartmouth.html']},
#  {'Name': 'William__Mary',
#   'State': 'VA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/VA_college_m_William__Mary.html']},
#  {'Name': 'Wake Forest',
#   'State': 'NC',
#   'URLs': ['https://www.tfrrs.org/teams/tf/NC_college_m_Wake_Forest.html']},
#  {'Name': 'Illinois',
#   'State': 'IL',
#   'URLs': ['https://www.tfrrs.org/teams/tf/IL_college_m_Illinois.html']},
#  {'Name': 'Michigan State',
#   'State': 'MI',
#   'URLs': ['https://www.tfrrs.org/teams/tf/MI_college_m_Michigan_State.html']},
#  {'Name': 'North_Carolina_St',
#   'State': 'NC',
#   'URLs': ['https://www.tfrrs.org/teams/tf/NC_college_m_North_Carolina_St.html']},
#  {'Name': 'Virginia Tech',
#   'State': 'VA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/VA_college_m_Virginia_Tech.html']},
#  {'Name': 'Clemson',
#   'State': 'SC',
#   'URLs': ['https://www.tfrrs.org/teams/tf/SC_college_m_Clemson.html']},
#  {'Name': 'Boston_U',
#   'State': 'MA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/MA_college_m_Boston_U.html']},
#  {'Name': 'Minnesota',
#   'State': 'MN',
#   'URLs': ['https://www.tfrrs.org/teams/tf/MN_college_m_Minnesota.html']},
#  {'Name': 'Texas_AM',
#   'State': 'TX',
#   'URLs': ['https://www.tfrrs.org/teams/tf/TX_college_m_Texas_AM.html']},
#  {'Name': 'Rutgers',
#   'State': 'NJ',
#   'URLs': ['https://www.tfrrs.org/teams/tf/NJ_college_m_Rutgers.html']},
#  {'Name': 'Navy',
#   'State': 'MD',
#   'URLs': ['https://www.tfrrs.org/teams/tf/MD_college_m_Navy.html']},
#  {'Name': 'Indiana_IN',
#   'State': 'IN',
#   'URLs': ['https://www.tfrrs.org/teams/tf/IN_college_m_Indiana_IN.html']},
#  {'Name': 'UMass Amherst',
#   'State': 'MA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/MA_college_m_UMass_Amherst.html']},
#  {'Name': 'Boston College',
#   'State': 'MA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/MA_college_m_Boston_College.html']},
#  {'Name': 'Villanova',
#   'State': 'PA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/PA_college_m_Villanova.html']},
#  {'Name': 'Alabama A&M',
#   'State': 'AL',
#   'URLs': ['https://www.tfrrs.org/teams/tf/AL_college_m_Alabama_AM.html']},
#  {'Name': 'Alabama-Birmingham',
#   'State': 'AL',
#   'URLs': ['https://www.tfrrs.org/teams/tf/AL_college_m_UAB.html']},
#  {'Name': 'Murray State',
#   'State': 'KY',
#   'URLs': ['https://www.tfrrs.org/teams/tf/KY_college_m_Murray_State.html']},
#  {'Name': 'St. Francis (PA)',
#   'State': 'PA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/PA_college_m_Saint_Francis_PA.html']},
#  {'Name': 'North Carolina Central',
#   'State': 'NC',
#   'URLs': ['https://www.tfrrs.org/teams/7636']},
#  {'Name': 'Loyola (IL)',
#   'State': 'IL',
#   'URLs': ['https://www.tfrrs.org/teams/tf/IL_college_m_Loyola_IL.html']},
#  {'Name': 'Chicago State',
#   'State': 'IL',
#   'URLs': ['https://www.tfrrs.org/teams/tf/IL_college_m_Chicago_State.html']},
#  {'Name': 'Texas A&M-Corpus Christi',
#   'State': 'TX',
#   'URLs': ['https://www.tfrrs.org/teams/tf/TX_college_m_Texas_AM_CC.html']},
#  {'Name': 'Hampton',
#   'State': 'VA',
#   'URLs': ['https://www.tfrrs.org/teams/tf/VA_college_m_Hampton.html']},
#  {'Name': 'South Carolina State',
#   'State': 'SC',
#   'URLs': ['https://www.tfrrs.org/teams/tf/SC_college_m_South_Carolina_State.html']},
#  {'Name': 'Hartford',
#   'State': 'CT',
#   'URLs': ['https://www.tfrrs.org/teams/tf/CT_college_m_Hartford.html']},
#  {'Name': 'Alabama A&M',
#   'State': 'AL',
#   'URLs': ['https://www.tfrrs.org/teams/tf/AL_college_m_Alabama_AM.html']}]

# %%
# try again
# 1. Import required libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# 2. Load complete list of schools
with open("all_teams.json") as f:
  all_schools_and_genders = json.load(f)
  f.close()


def parse_athlete_performance(html_content, team):
    """Parses HTML content to extract athlete performance details
    
    Parameters:
    - html_content (str): HTML content of the web page
    - team (str): The name of the team to include in the performance details
    
    Returns:
    - List[Dict]: A list of dictionaries where each dictionary contains performance details of an athlete """
    
    soup = BeautifulSoup(html_content, 'html.parser')
    performances = []

    table = soup.find('table', {'class': 'tablesaw'})
    if not table:
        return performances

    for row in table.find_all('tr')[1:]:
        columns = row.find_all('td')
        if len(columns) == 4:
            performance = {
                'Event Name': columns[0].text.strip(),
                'Athlete Name': columns[1].text.strip(),
                'Team': team,
                'Mark': columns[3].text.strip(),
                'Event Type': 'Individual' if len(columns[1].find_all('a')) == 1 else 'Relay'
            }
            performances.append(performance)

    return performances

# initialize
all_performances = []

# standard formatting of links in tfrrs
base_url = 'https://www.tfrrs.org'

# loop through each school and gender to fetch and parse performances
for school in all_schools_and_genders:
        team_name = school["team"]
        print(f"Getting data for {team_name}")
        url = base_url + school["url"]
        response = requests.get(url)

        # print if failed
        if response.status_code == 200:
            performances = parse_athlete_performance(response.text, team_name)
            all_performances.extend(performances)
        else:
            print(f"No data for {team_name}")
                
# convert it into a dataframe
df = pd.DataFrame(all_performances)
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 55
#      53 team_name = school["team"]
#      54 url = base_url + school["url"]
# ---> 55 response = requests.get(url)
#      57 # print if failed
#      58 if response.status_code == 200:
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~/anaconda3/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/anaconda3/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/anaconda3/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/anaconda3/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:
